# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import datetime
import os.path

# %%
# Establecer la semilla en NumPy
np.random.seed(42)

# Establecer la semilla en TensorFlow
tf.random.set_seed(42)

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 32)                262176
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 263,402
# Trainable params: 263,402
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
# Definir el callback de EarlyStopping
early_stopping_val_loss = EarlyStopping(monitor='val_loss',
                                        patience=5, restore_best_weights=True)
early_stopping_val_accuracy = EarlyStopping(monitor="val_accuracy",
                                            patience=5, restore_best_weights=True)

# %%
# Compilación del modelo
model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)

# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()

print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=300,
                    batch_size= 512, validation_data=(x_val_scaled, y_val),
                    callbacks=[early_stopping_val_loss, early_stopping_val_accuracy])
# Out:
# Epoch 1/300
# 79/79 [==============================] - 11s 18ms/step - loss: 2.0720 - accuracy: 0.2218 - val_loss: 1.8593 - val_accuracy: 0.3451
# Epoch 2/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.7412 - accuracy: 0.3878 - val_loss: 1.6627 - val_accuracy: 0.4177
# Epoch 3/300
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5593 - accuracy: 0.4527 - val_loss: 1.5085 - val_accuracy: 0.4726
# Epoch 4/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4394 - accuracy: 0.4931 - val_loss: 1.4354 - val_accuracy: 0.4958
# Epoch 5/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3668 - accuracy: 0.5155 - val_loss: 1.3727 - val_accuracy: 0.5220
# Epoch 6/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3148 - accuracy: 0.5333 - val_loss: 1.3239 - val_accuracy: 0.5370
# Epoch 7/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2733 - accuracy: 0.5503 - val_loss: 1.3059 - val_accuracy: 0.5394
# Epoch 8/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2386 - accuracy: 0.5659 - val_loss: 1.2855 - val_accuracy: 0.5504
# Epoch 9/300
# 79/79 [==============================] - 1s 11ms/step - loss: 1.2091 - accuracy: 0.5740 - val_loss: 1.2640 - val_accuracy: 0.5599
# Epoch 10/300
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1819 - accuracy: 0.5839 - val_loss: 1.2373 - val_accuracy: 0.5676
# Epoch 11/300
# 79/79 [==============================] - 1s 13ms/step - loss: 1.1650 - accuracy: 0.5916 - val_loss: 1.2204 - val_accuracy: 0.5773
# Epoch 12/300
# 79/79 [==============================] - 1s 13ms/step - loss: 1.1481 - accuracy: 0.6004 - val_loss: 1.1998 - val_accuracy: 0.5831
# Epoch 13/300
# 79/79 [==============================] - 1s 13ms/step - loss: 1.1255 - accuracy: 0.6065 - val_loss: 1.2070 - val_accuracy: 0.5820
# Epoch 14/300
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1057 - accuracy: 0.6151 - val_loss: 1.2132 - val_accuracy: 0.5774
# Epoch 15/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0941 - accuracy: 0.6170 - val_loss: 1.1791 - val_accuracy: 0.5920
# Epoch 16/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0706 - accuracy: 0.6276 - val_loss: 1.1888 - val_accuracy: 0.5758
# Epoch 17/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0644 - accuracy: 0.6284 - val_loss: 1.1623 - val_accuracy: 0.5963
# Epoch 18/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0448 - accuracy: 0.6367 - val_loss: 1.2112 - val_accuracy: 0.5752
# Epoch 19/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0347 - accuracy: 0.6408 - val_loss: 1.1466 - val_accuracy: 0.5983
# Epoch 20/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0217 - accuracy: 0.6441 - val_loss: 1.1345 - val_accuracy: 0.6025
# Epoch 21/300
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0124 - accuracy: 0.6454 - val_loss: 1.1648 - val_accuracy: 0.5918
# Epoch 22/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9971 - accuracy: 0.6527 - val_loss: 1.1439 - val_accuracy: 0.5994
# Epoch 23/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9802 - accuracy: 0.6601 - val_loss: 1.1460 - val_accuracy: 0.6000
# Epoch 24/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9743 - accuracy: 0.6619 - val_loss: 1.1258 - val_accuracy: 0.6070
# Epoch 25/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9606 - accuracy: 0.6659 - val_loss: 1.0969 - val_accuracy: 0.6162
# Epoch 26/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9483 - accuracy: 0.6729 - val_loss: 1.0949 - val_accuracy: 0.6178
# Epoch 27/300
# 79/79 [==============================] - 1s 13ms/step - loss: 0.9448 - accuracy: 0.6696 - val_loss: 1.0931 - val_accuracy: 0.6191
# Epoch 28/300
# 79/79 [==============================] - 1s 12ms/step - loss: 0.9330 - accuracy: 0.6767 - val_loss: 1.0943 - val_accuracy: 0.6164
# Epoch 29/300
# 79/79 [==============================] - 1s 13ms/step - loss: 0.9272 - accuracy: 0.6761 - val_loss: 1.0910 - val_accuracy: 0.6210
# Epoch 30/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9092 - accuracy: 0.6844 - val_loss: 1.0838 - val_accuracy: 0.6229
# Epoch 31/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9050 - accuracy: 0.6848 - val_loss: 1.1371 - val_accuracy: 0.6060
# Epoch 32/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9006 - accuracy: 0.6874 - val_loss: 1.0930 - val_accuracy: 0.6175
# Epoch 33/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8887 - accuracy: 0.6935 - val_loss: 1.1018 - val_accuracy: 0.6198
# Epoch 34/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8840 - accuracy: 0.6922 - val_loss: 1.0793 - val_accuracy: 0.6271
# Epoch 35/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8746 - accuracy: 0.6965 - val_loss: 1.0858 - val_accuracy: 0.6189
# Epoch 36/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8685 - accuracy: 0.7008 - val_loss: 1.1018 - val_accuracy: 0.6172
# Epoch 37/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8593 - accuracy: 0.7024 - val_loss: 1.0708 - val_accuracy: 0.6302
# Epoch 38/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8475 - accuracy: 0.7074 - val_loss: 1.0742 - val_accuracy: 0.6279
# Epoch 39/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8458 - accuracy: 0.7075 - val_loss: 1.0891 - val_accuracy: 0.6233
# Epoch 40/300
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8349 - accuracy: 0.7106 - val_loss: 1.0955 - val_accuracy: 0.6245
# Epoch 41/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8304 - accuracy: 0.7139 - val_loss: 1.0849 - val_accuracy: 0.6255
# Epoch 42/300
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8279 - accuracy: 0.7147 - val_loss: 1.0833 - val_accuracy: 0.6285

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:00:47.380263

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
# Calcular las métricas
acc_train = model.evaluate(x_train_scaled, y_train, verbose=0)[1]
acc_test = model.evaluate(x_test_scaled, y_test, verbose=0)[1]
loss_train = model.evaluate(x_train_scaled, y_train, verbose=0)[0]
loss_test = model.evaluate(x_test_scaled, y_test, verbose=0)[0]

# %%
print('Accuracy (train): %.3f' % (acc_train * 100.0))
print('Accuracy (test): %.3f' % (acc_test * 100.0))
# Out:
# Accuracy (train): 71.342
# Accuracy (test): 62.560

# %%
print('Cross Entropy Loss (train): %.3f' % loss_train)
print('Cross Entropy Loss (test): %.3f' % loss_test)
# Out:
# Cross Entropy Loss (train): 0.840
# Cross Entropy Loss (test): 1.070

# %%
# Obtener la fecha y hora actual:
now = datetime.datetime.now()

# Crear un DataFrame con los resultados:
data = {'Fecha': [now],
        'Nombre del notebook': ['230630_base_cnn-cifar10.ipynb'],
        'Accuracy (train)': [acc_train],
        'Accuracy (test)': [acc_test],
        'Cross Entropy Loss (train)': [loss_train],
        'Cross Entropy Loss (test)': [loss_test]}

df = pd.DataFrame(data)

# Ubicación del archivo:
ruta_archivo = '/content/drive/MyDrive/NDS_2023/Isi/Entregable/CIFAR10_resultados.xlsx'

# Cargar el archivo existente si existe, de lo contrario, crear uno nuevo:
if os.path.exists(ruta_archivo):
    existing_df = pd.read_excel(ruta_archivo)
else:
    existing_df = pd.DataFrame()

# Agregar el nuevo DataFrame al DataFrame existente:
updated_df = existing_df.append(df)

# Guardar el DataFrame actualizado en el archivo de Excel:
updated_df.to_excel(ruta_archivo, index=False)
# Out:
# <ipython-input-20-8799e47c2e72>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   updated_df = existing_df.append(df)

# %%
plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/NDS_2023/Isi/Entregable/models/"

# Guardar el modelo
model.save(ruta_googledrive + '230630_base_cnn-cifar10_model.h5')
